# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt
X = [[i] for i in [2, 8, 0, 4, 1, 9, 9, 0, 10, 12]]

# %%
Z = linkage(X, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

# %%
X
# Out:
# [[2], [8], [0], [4], [1], [9], [9], [0], [10], [12]]

# %%
Z
# Out:
# array([[ 2.,  7.,  0.,  2.],
#        [ 5.,  6.,  0.,  2.],
#        [ 0.,  4.,  1.,  2.],
#        [10., 12.,  1.,  4.],
#        [ 1., 11.,  1.,  3.],
#        [ 8., 14.,  1.,  4.],
#        [ 3., 13.,  2.,  5.],
#        [ 9., 15.,  2.,  5.],
#        [16., 17.,  4., 10.]])
